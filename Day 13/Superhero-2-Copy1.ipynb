# %%
pd.DataFrame.from_dict(unique_details)
# Out:
#             Unique_powers            Hero
# 0          Thirstokinesis    Kool-Aid Man
# 1      Intuitive aptitude           Sylar
# 2            Hyperkinesis   Cameron Hicks
# 3       Hair Manipulation          Medusa
# 4    Electrical Transport         Electro
# 5            Anti-Gravity            Kang
# 6       Spatial Awareness   Cameron Hicks
# 7              Biokinesis      Apocalypse
# 8                Omnitrix          Ben 10
# 9             Speed Force        Flash II
# 10          Phoenix Force         Phoenix
# 11  Molecular Dissipation    Dr Manhattan
# 12                 Banish  Doctor Strange
# 13         Changing Armor    Valerie Hart
